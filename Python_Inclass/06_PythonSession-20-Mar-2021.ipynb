# %% [markdown]
# <img src="https://docs.google.com/uc?id=14xeXxFrVRjvOoUYWn_GuyE-v84wVzrqr" class="img-fluid" alt="CLRWY" width="400" height="200">

# %% [markdown]
# <h1><p style="text-align: center; color:darkblue">Python In-Class, <br>20 March 2021</p><h1>

# %%
"orange"[-6]
# Out:
# 'o'

# %%
"orange"[0]
# Out:
# 'o'

# %%
"orange"[-1]
# Out:
# 'e'

# %%
"orange"[-5:-2]
# Out:
# 'ran'

# %%
"orange"[::-1]
# Out:
# 'egnaro'

# %%
"ey edip adanada pide ye"[::-1]
# Out:
# 'ey edip adanada pide ye'

# %%
"orange"[-2:-5:-1]
# Out:
# 'gna'

# %%
"orange"[4:1:-1]
# Out:
# 'gna'

# %%
"orange"[4:1]
# Out:
# ''

# %%
"orange"[-3:-6]
# Out:
# ''

# %%
"orange"[4:1:-1]
# Out:
# 'gna'

# %%
"orange"[-3:-6:-1]
# Out:
# 'nar'

# %%
len("orange")
# Out:
# 6

# %%
"upper" * 3
# Out:
# 'upperupperupper'

# %%
3 * "upper"
# Out:
# 'upperupperupper'

# %%
"upperupperupper"

# %%
"upper" + "upper" + "upper"
# Out:
# 'upperupperupper'

# %%
"upper" * 3
# Out:
# 'upperupperupper'

# %%
a = "upper"

# %%
a*3
# Out:
# 'upperupperupper'

# %%
print("clarusway")
# Out:
# clarusway

# %%
print(* "clarusway")
# Out:
# c l a r u s w a y

# %%
string_1 = 'I am angry...'

# %%
print(* string_1)
# Out:
# I   a m   a n g r y . . .

# %%
string_2 = '1453'

# %%
print(* string_2)
# Out:
# 1 4 5 3

# %%
print(* 'joseph@clarusway.com')
# Out:
# j o s e p h @ c l a r u s w a y . c o m

# %%
x = "a"

# %%
x
# Out:
# 'a'

# %%
x = x + "h"  # x += "h"
x
# Out:
# 'ah'

# %%
x += "m"
x
# Out:
# 'ahm'

# %%
x += "e"
x
# Out:
# 'ahme'

# %%
x += "t"
x
# Out:
# 'ahmet'

# %%
x *= 3

# %%
x
# Out:
# 'ahmetahmetahmet'

# %%
print("{state} is the most {adjective} state of the {country}".\
       format(state = "California", country = "USA", adjective = "crowded"))
# Out:
# California is the most crowded state of the USA

# %%
state = "California"
country = "USA"
adjective = "crowded"

# %%
print("{} is the most {} state of the {}".\
       format(state, country, adjective))
# Out:
# California is the most USA state of the crowded

# %%
print("{} is the most {} state of the {}".\
       format(state, adjective, country))
# Out:
# California is the most crowded state of the USA

# %%
print("{state} is the most {adjective} state of the {country}".\
       format(state, country, adjective))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-e851008d0b2a> in <module>
#       1 print("{state} is the most {adjective} state of the {country}".\
# ----> 2        format(state, country, adjective))
#
# KeyError: 'state'

# %%
print("{0} is the most {2} state of the {1}".\
       format(state, country, adjective))
# Out:
# California is the most crowded state of the USA

# %%
print("{}-{}".format("ahmet", "mehmet"))
# Out:
# ahmet-mehmet

# %%
print("{} is the most {adjective} state of the {country}".\
       format("California", country = "USA", adjective = "crowded"))
# Out:
# California is the most crowded state of the USA

# %%
print("{} is the most {adjective} state of the {}".\
       format("USA", "California", adjective = "crowded"))
# Out:
# USA is the most crowded state of the California

# %%
print("{y}-{}-{x}-{}".format(y = "a", "c", "d", x = "b"))
# Out:
#   File "<ipython-input-58-be0923b617aa>", line 1
#     print("{y}-{}-{x}-{}".format(y = "a", "c", "d", x = "b"))
#                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
print("{y}-{}-{x}-{}".format(1, "d", x = "b", y = 5))
# Out:
# 5-1-b-d

# %%
print("{y}-{1}-{x}-{0}".format(1, "d", x = "b", y = 5))
# Out:
# 5-d-b-1
